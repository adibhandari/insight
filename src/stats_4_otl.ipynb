# %%
#merge data from several states
import numpy as np
import pandas as pd
import json
from pandas.io.json import json_normalize
import matplotlib.pyplot as plt
import pprint
import seaborn as sns
from pprint import pprint

# %%
alldogs_merged = pd.read_csv('./data/alldogs_scoped_merged.csv')
state={'CA':'Los Angeles', 'MN': 'Minneapolis', 'NY':'New York', 'TX': 'Houston'}

# %%
len(alldogs_merged)
# Out:
# 184542

# %%
alldogs_merged.head()
# Out:
#          id organization_id  \
# 0  33853923          CA2395
# 1  33853969          CA2395
# 2  34004290          CA2395
# 3  34042721          CA2395
# 4  34079567          CA2395
#
#                                                  url    age  gender    size  \
# 0  https://www.petfinder.com/dog/sunny-33853923/c...   Baby  Female   Small
# 1  https://www.petfinder.com/dog/batman-33853969/...  Young    Male   Small
# 2  https://www.petfinder.com/dog/benji-34004290/c...  Young    Male  Medium
# 3  https://www.petfinder.com/dog/zuma-34042721/ca...  Adult  Female  Medium
# 4  https://www.petfinder.com/dog/diego-34079567/c...  Young    Male  Medium
#
#      coat tags    name   status  ... attributes.declawed  \
# 0     NaN   []   Sunny  adopted  ...                 NaN
# 1   Short   []  Batman  adopted  ...                 NaN
# 2   Short   []   Benji  adopted  ...                 NaN
# 3   Short   []    Zuma  adopted  ...                 NaN
# 4  Medium   []   Diego  adopted  ...                 NaN
#
#   attributes.special_needs  attributes.shots_current environment.children  \
# 0                    False                      True                  NaN
# 1                    False                      True                  NaN
# 2                    False                      True                  NaN
# 3                    False                      True                  NaN
# 4                    False                      True                  NaN
#
#   environment.dogs  environment.cats  contact.address.city  \
# 0              NaN               NaN           Los Angeles
# 1              NaN               NaN           Los Angeles
# 2              NaN               NaN           Los Angeles
# 3              NaN               NaN           Los Angeles
# 4              NaN               NaN           Los Angeles
#
#   contact.address.state contact.address.postcode adoption_time
# 0                    CA                    90013            19
# 1                    CA                    90013            29
# 2                    CA                    90013            18
# 3                    CA                    90013            57
# 4                    CA                    90013             8
#
# [5 rows x 32 columns]

# %%
mean_adpt_time = {}
#create a dict with each state and average adoption time
for current_state,current_city in state.items():
    key = current_state
    val = alldogs_merged[alldogs_merged['contact.address.state'] == current_state]['adoption_time'].mean()
    mean_adpt_time[key] = val
pprint(mean_adpt_time)
# Out:
# {'CA': 184.01237496363595,
#  'MN': 102.96562054208273,
#  'NY': 227.69666935576814,
#  'TX': 140.0659042704393}

# %%
alldogs_merged[(alldogs_merged['contact.address.state'] == current_state) & (alldogs_merged['size'] == 'Small')]
# Out:
#              id organization_id  \
# 0      33853923          CA2395
# 1      33853969          CA2395
# 5      34079609          CA2395
# 6      34410228          CA2395
# 7      34455079          CA2395
# 8      34531968          CA2395
# 10     34636197          CA2395
# 12     34818363          CA2395
# 13     34849899          CA2395
# 16     35367052          CA2395
# 17     35595740          CA2395
# 18     36142021          CA2395
# 19     36282211          CA2395
# 20     36390317          CA2395
# 21     36456028          CA2395
# 22     37063954          CA2395
# 24     37188219          CA2395
# 26     37378884          CA2395
# 27     37378989          CA2395
# 28     37435569          CA2395
# 29     37469433          CA2395
# 30     37582387          CA2395
# 31     37772346          CA2395
# 36     38525382          CA2395
# 38     38914342          CA2395
# 41     39737745          CA2395
# 42     39737834          CA2395
# 44     39936080          CA2395
# 48     40942935          CA2395
# 49     41007769          CA2395
# ...         ...             ...
# 44655  32231959          CA1278
# 44656  32232048          CA1278
# 44657  32454683          CA1278
# 44659  32678990          CA1278
# 44660  32942833          CA1278
# 44661  33056378          CA1278
# 44662  33089059          CA1278
# 44663  33089066          CA1278
# 44664  33205658          CA1278
# 44665  33264537          CA1278
# 44666  33264626          CA1278
# 44667  33329154          CA1278
# 44668  33894428          CA1278
# 44669  33894440          CA1278
# 44670  33894492          CA1278
# 44671  33901968          CA1278
# 44672  33928845          CA1278
# 44673  34015373          CA1278
# 44674  34015381          CA1278
# 44675  34162142          CA1278
# 44676  34209947          CA1278
# 44677  34448495          CA1278
# 44679  34857770          CA1278
# 44680  34857777          CA1278
# 44681  34857793          CA1278
# 44682  37307031          CA1278
# 44683  37713981          CA1278
# 44684  37995977          CA1278
# 44685  37997594          CA1278
# 44686  38176265          CA1278
#
#                                                      url    age  gender  \
# 0      https://www.petfinder.com/dog/sunny-33853923/c...   Baby  Female
# 1      https://www.petfinder.com/dog/batman-33853969/...  Young    Male
# 5      https://www.petfinder.com/dog/peaches-34079609...  Adult  Female
# 6      https://www.petfinder.com/dog/emmylou-34410228...  Young  Female
# 7      https://www.petfinder.com/dog/newton-34455079/...  Young    Male
# 8      https://www.petfinder.com/dog/rafferty-3453196...  Young    Male
# 10     https://www.petfinder.com/dog/bobby-34636197/c...  Young    Male
# 12     https://www.petfinder.com/dog/patrick-34818363...  Young    Male
# 13     https://www.petfinder.com/dog/justin-bieber-34...   Baby    Male
# 16     https://www.petfinder.com/dog/mimi-35367052/ca...  Young  Female
# 17     https://www.petfinder.com/dog/piper-35595740/c...  Young  Female
# 18     https://www.petfinder.com/dog/ginger-36142021/...  Young  Female
# 19     https://www.petfinder.com/dog/linus-36282211/c...   Baby    Male
# 20     https://www.petfinder.com/dog/milo-36390317/ca...  Young    Male
# 21     https://www.petfinder.com/dog/candy-36456028/c...   Baby  Female
# 22     https://www.petfinder.com/dog/rudy-37063954/ca...  Young    Male
# 24     https://www.petfinder.com/dog/luke-37188219/ca...  Young    Male
# 26     https://www.petfinder.com/dog/winky-37378884/c...  Young    Male
# 27     https://www.petfinder.com/dog/marley-37378989/...  Adult    Male
# 28     https://www.petfinder.com/dog/waylon-37435569/...  Young    Male
# 29     https://www.petfinder.com/dog/jose-37469433/ca...  Young  Female
# 30     https://www.petfinder.com/dog/bindi-37582387/c...  Adult  Female
# 31     https://www.petfinder.com/dog/mint-37772346/ca...   Baby    Male
# 36     https://www.petfinder.com/dog/alwin-38525382/c...  Young    Male
# 38     https://www.petfinder.com/dog/leon-38914342/ca...  Young    Male
# 41     https://www.petfinder.com/dog/rumi-39737745/ca...   Baby  Female
# 42     https://www.petfinder.com/dog/bert-39737834/ca...  Adult    Male
# 44     https://www.petfinder.com/dog/pierre-39936080/...  Young    Male
# 48     https://www.petfinder.com/dog/franklin-4094293...  Young    Male
# 49     https://www.petfinder.com/dog/marley-41007769/...  Adult    Male
# ...                                                  ...    ...     ...
# 44655  https://www.petfinder.com/dog/charlie-32231959...  Young    Male
# 44656  https://www.petfinder.com/dog/rowdy-32232048/c...  Young    Male
# 44657  https://www.petfinder.com/dog/lambchop-3245468...  Young  Female
# 44659  https://www.petfinder.com/dog/pixie-32678990/c...  Young  Female
# 44660  https://www.petfinder.com/dog/bella-32942833/c...  Young  Female
# 44661  https://www.petfinder.com/dog/diego-33056378/c...  Young    Male
# 44662  https://www.petfinder.com/dog/meggy-33089059/c...  Young  Female
# 44663  https://www.petfinder.com/dog/daisy-33089066/c...  Young  Female
# 44664  https://www.petfinder.com/dog/mikey-33205658/c...   Baby    Male
# 44665  https://www.petfinder.com/dog/chiquita-3326453...  Young  Female
# 44666  https://www.petfinder.com/dog/precious-3326462...  Young  Female
# 44667  https://www.petfinder.com/dog/uba-33329154/ca/...   Baby    Male
# 44668  https://www.petfinder.com/dog/sugar-33894428/c...  Young  Female
# 44669  https://www.petfinder.com/dog/daphne-33894440/...  Young  Female
# 44670  https://www.petfinder.com/dog/pauley-33894492/...  Young    Male
# 44671  https://www.petfinder.com/dog/shy-boy-33901968...  Young    Male
# 44672  https://www.petfinder.com/dog/jojo-33928845/ca...  Young    Male
# 44673  https://www.petfinder.com/dog/alfie-34015373/c...  Young    Male
# 44674  https://www.petfinder.com/dog/ollie-34015381/c...  Young    Male
# 44675  https://www.petfinder.com/dog/zac-and-zoie-341...   Baby  Female
# 44676  https://www.petfinder.com/dog/whitley-34209947...   Baby  Female
# 44677  https://www.petfinder.com/dog/gracie-34448495/...  Young  Female
# 44679  https://www.petfinder.com/dog/chelsie-34857770...   Baby  Female
# 44680  https://www.petfinder.com/dog/cricket-34857777...   Baby  Female
# 44681  https://www.petfinder.com/dog/checkers-3485779...   Baby  Female
# 44682  https://www.petfinder.com/dog/paco-37307031/ca...  Young    Male
# 44683  https://www.petfinder.com/dog/gunther-37713981...  Young    Male
# 44684  https://www.petfinder.com/dog/bubbie-37995977/...  Young    Male
# 44685  https://www.petfinder.com/dog/pj-37997594/ca/s...   Baby    Male
# 44686  https://www.petfinder.com/dog/bubbie-38176265/...  Adult    Male
#
#         size    coat                                               tags  \
# 0      Small     NaN                                                 []
# 1      Small   Short                                                 []
# 5      Small    Long                                                 []
# 6      Small   Short                                                 []
# 7      Small  Medium                                                 []
# 8      Small   Short                                                 []
# 10     Small  Medium                                                 []
# 12     Small   Short                                                 []
# 13     Small    Long                                                 []
# 16     Small  Medium                                                 []
# 17     Small    Long                                                 []
# 18     Small   Short                                                 []
# 19     Small   Short                                                 []
# 20     Small  Medium                                                 []
# 21     Small  Medium                                                 []
# 22     Small  Medium                                                 []
# 24     Small  Medium                                                 []
# 26     Small  Medium                                                 []
# 27     Small    Long                                                 []
# 28     Small   Short                                                 []
# 29     Small   Short                                                 []
# 30     Small    Long                                                 []
# 31     Small    Long                                                 []
# 36     Small     NaN                                                 []
# 38     Small    Long                                                 []
# 41     Small   Short                                                 []
# 42     Small  Medium                                                 []
# 44     Small    Long                                                 []
# 48     Small     NaN  ['Loving', 'mildy energetic', 'cuddly', 'sweet...
# 49     Small  Medium    ['Calm', 'loving', 'happy', 'playful', 'sweet']
# ...      ...     ...                                                ...
# 44655  Small   Short                                                 []
# 44656  Small   Short                                                 []
# 44657  Small  Medium                                                 []
# 44659  Small   Short                                                 []
# 44660  Small   Short                                                 []
# 44661  Small   Short                                                 []
# 44662  Small   Short                                                 []
# 44663  Small   Short                                                 []
# 44664  Small    Long                                                 []
# 44665  Small   Short                                                 []
# 44666  Small   Short                                                 []
# 44667  Small   Short                                                 []
# 44668  Small   Short                                                 []
# 44669  Small     NaN                                                 []
# 44670  Small     NaN                                                 []
# 44671  Small     NaN                                                 []
# 44672  Small     NaN                                                 []
# 44673  Small     NaN                                                 []
# 44674  Small     NaN                                                 []
# 44675  Small     NaN                                                 []
# 44676  Small     NaN                                                 []
# 44677  Small     NaN                                                 []
# 44679  Small     NaN                                                 []
# 44680  Small     NaN                                                 []
# 44681  Small     NaN                                                 []
# 44682  Small     NaN                                                 []
# 44683  Small     NaN                                                 []
# 44684  Small     NaN                                                 []
# 44685  Small     NaN                                                 []
# 44686  Small   Short                                                 []
#
#                 name   status  ... attributes.declawed  \
# 0              Sunny  adopted  ...                 NaN
# 1             Batman  adopted  ...                 NaN
# 5            Peaches  adopted  ...                 NaN
# 6            EmmyLou  adopted  ...                 NaN
# 7             Newton  adopted  ...                 NaN
# 8           Rafferty  adopted  ...                 NaN
# 10             Bobby  adopted  ...                 NaN
# 12           Patrick  adopted  ...                 NaN
# 13     Justin Bieber  adopted  ...                 NaN
# 16              Mimi  adopted  ...                 NaN
# 17             Piper  adopted  ...                 NaN
# 18            Ginger  adopted  ...                 NaN
# 19             Linus  adopted  ...                 NaN
# 20              Milo  adopted  ...                 NaN
# 21             Candy  adopted  ...                 NaN
# 22              Rudy  adopted  ...                 NaN
# 24              Luke  adopted  ...                 NaN
# 26             Winky  adopted  ...                 NaN
# 27            Marley  adopted  ...                 NaN
# 28            Waylon  adopted  ...                 NaN
# 29              Jose  adopted  ...                 NaN
# 30             Bindi  adopted  ...                 NaN
# 31              Mint  adopted  ...                 NaN
# 36             Alwin  adopted  ...                 NaN
# 38              Leon  adopted  ...                 NaN
# 41              Rumi  adopted  ...                 NaN
# 42              Bert  adopted  ...                 NaN
# 44            Pierre  adopted  ...                 NaN
# 48          Franklin  adopted  ...                 NaN
# 49            Marley  adopted  ...                 NaN
# ...              ...      ...  ...                 ...
# 44655        Charlie  adopted  ...                 NaN
# 44656          Rowdy  adopted  ...                 NaN
# 44657       Lambchop  adopted  ...                 NaN
# 44659          Pixie  adopted  ...                 NaN
# 44660          Bella  adopted  ...                 NaN
# 44661          Diego  adopted  ...                 NaN
# 44662          Meggy  adopted  ...                 NaN
# 44663          Daisy  adopted  ...                 NaN
# 44664          Mikey  adopted  ...                 NaN
# 44665       Chiquita  adopted  ...                 NaN
# 44666       Precious  adopted  ...                 NaN
# 44667            Uba  adopted  ...                 NaN
# 44668          Sugar  adopted  ...                 NaN
# 44669         Daphne  adopted  ...                 NaN
# 44670         Pauley  adopted  ...                 NaN
# 44671        Shy boy  adopted  ...                 NaN
# 44672           Jojo  adopted  ...                 NaN
# 44673          Alfie  adopted  ...                 NaN
# 44674          Ollie  adopted  ...                 NaN
# 44675     Zac & Zoie  adopted  ...                 NaN
# 44676        Whitley  adopted  ...                 NaN
# 44677         Gracie  adopted  ...                 NaN
# 44679        Chelsie  adopted  ...                 NaN
# 44680        Cricket  adopted  ...                 NaN
# 44681       Checkers  adopted  ...                 NaN
# 44682           Paco  adopted  ...                 NaN
# 44683        Gunther  adopted  ...                 NaN
# 44684         Bubbie  adopted  ...                 NaN
# 44685             PJ  adopted  ...                 NaN
# 44686         Bubbie  adopted  ...                 NaN
#
#       attributes.special_needs  attributes.shots_current environment.children  \
# 0                        False                      True                  NaN
# 1                        False                      True                  NaN
# 5                        False                      True                  NaN
# 6                        False                     False                False
# 7                        False                      True                  NaN
# 8                        False                      True                  NaN
# 10                       False                      True                  NaN
# 12                       False                      True                  NaN
# 13                       False                      True                  NaN
# 16                       False                      True                  NaN
# 17                       False                      True                  NaN
# 18                       False                      True                  NaN
# 19                       False                      True                  NaN
# 20                       False                      True                  NaN
# 21                       False                      True                  NaN
# 22                       False                      True                  NaN
# 24                       False                      True                  NaN
# 26                       False                      True                  NaN
# 27                       False                      True                  NaN
# 28                       False                      True                  NaN
# 29                       False                      True                  NaN
# 30                       False                      True                  NaN
# 31                       False                      True                  NaN
# 36                       False                      True                 True
# 38                       False                     False                 True
# 41                       False                      True                 True
# 42                       False                      True                 True
# 44                       False                      True                 True
# 48                       False                     False                 True
# 49                       False                     False                 True
# ...                        ...                       ...                  ...
# 44655                    False                      True                  NaN
# 44656                    False                      True                  NaN
# 44657                    False                      True                  NaN
# 44659                    False                      True                  NaN
# 44660                    False                      True                  NaN
# 44661                    False                      True                  NaN
# 44662                    False                      True                  NaN
# 44663                    False                      True                  NaN
# 44664                    False                      True                  NaN
# 44665                    False                      True                  NaN
# 44666                    False                      True                  NaN
# 44667                    False                      True                  NaN
# 44668                    False                      True                  NaN
# 44669                    False                      True                  NaN
# 44670                    False                      True                  NaN
# 44671                    False                      True                  NaN
# 44672                    False                      True                  NaN
# 44673                    False                      True                  NaN
# 44674                    False                      True                  NaN
# 44675                    False                      True                  NaN
# 44676                    False                      True                  NaN
# 44677                    False                      True                  NaN
# 44679                    False                      True                  NaN
# 44680                    False                     False                  NaN
# 44681                    False                     False                  NaN
# 44682                    False                      True                  NaN
# 44683                    False                      True                  NaN
# 44684                    False                      True                  NaN
# 44685                    False                      True                  NaN
# 44686                    False                      True                  NaN
#
#       environment.dogs  environment.cats  contact.address.city  \
# 0                  NaN               NaN           Los Angeles
# 1                  NaN               NaN           Los Angeles
# 5                  NaN               NaN           Los Angeles
# 6                  NaN               NaN           Los Angeles
# 7                  NaN               NaN           Los Angeles
# 8                  NaN               NaN           Los Angeles
# 10                 NaN               NaN           Los Angeles
# 12                 NaN               NaN           Los Angeles
# 13                 NaN               NaN           Los Angeles
# 16                 NaN               NaN           Los Angeles
# 17                 NaN               NaN           Los Angeles
# 18                 NaN               NaN           Los Angeles
# 19                 NaN               NaN           Los Angeles
# 20                 NaN               NaN           Los Angeles
# 21                 NaN               NaN           Los Angeles
# 22                 NaN               NaN           Los Angeles
# 24                 NaN               NaN           Los Angeles
# 26                 NaN               NaN           Los Angeles
# 27                 NaN               NaN           Los Angeles
# 28                 NaN               NaN           Los Angeles
# 29                 NaN               NaN           Los Angeles
# 30                 NaN               NaN           Los Angeles
# 31                 NaN               NaN           Los Angeles
# 36                True              True           Los Angeles
# 38                True              True           Los Angeles
# 41                True              True           Los Angeles
# 42                True              True           Los Angeles
# 44                True               NaN           Los Angeles
# 48                True              True           Los Angeles
# 49                True              True           Los Angeles
# ...                ...               ...                   ...
# 44655              NaN               NaN           Studio City
# 44656              NaN               NaN           Studio City
# 44657              NaN               NaN           Studio City
# 44659              NaN               NaN           Studio City
# 44660              NaN               NaN           Studio City
# 44661              NaN               NaN           Studio City
# 44662              NaN               NaN           Studio City
# 44663              NaN               NaN           Studio City
# 44664              NaN               NaN           Studio City
# 44665              NaN               NaN           Studio City
# 44666              NaN               NaN           Studio City
# 44667              NaN               NaN           Studio City
# 44668              NaN               NaN           Studio City
# 44669              NaN               NaN           Studio City
# 44670              NaN               NaN           Studio City
# 44671              NaN               NaN           Studio City
# 44672              NaN               NaN           Studio City
# 44673              NaN               NaN           Studio City
# 44674              NaN               NaN           Studio City
# 44675              NaN               NaN           Studio City
# 44676              NaN               NaN           Studio City
# 44677              NaN               NaN           Studio City
# 44679              NaN               NaN           Studio City
# 44680              NaN               NaN           Studio City
# 44681              NaN               NaN           Studio City
# 44682              NaN               NaN           Studio City
# 44683              NaN               NaN           Studio City
# 44684              NaN               NaN           Studio City
# 44685              NaN               NaN           Studio City
# 44686              NaN               NaN           Studio City
#
#       contact.address.state contact.address.postcode adoption_time
# 0                        CA                    90013            19
# 1                        CA                    90013            29
# 5                        CA                    90013            33
# 6                        CA                    90013            13
# 7                        CA                    90013            14
# 8                        CA                    90013            32
# 10                       CA                    90013            25
# 12                       CA                    90013             5
# 13                       CA                    90013             1
# 16                       CA                    90013            34
# 17                       CA                    90013            10
# 18                       CA                    90013            16
# 19                       CA                    90013            36
# 20                       CA                    90013            30
# 21                       CA                    90013            22
# 22                       CA                    90013            44
# 24                       CA                    90013            25
# 26                       CA                    90013            97
# 27                       CA                    90013            49
# 28                       CA                    90013             4
# 29                       CA                    90013            36
# 30                       CA                    90013             4
# 31                       CA                    90013             6
# 36                       CA                    90013           125
# 38                       CA                    90013            42
# 41                       CA                    90013            28
# 42                       CA                    90013            70
# 44                       CA                    90013            25
# 48                       CA                    90013             5
# 49                       CA                    90013            34
# ...                     ...                      ...           ...
# 44655                    CA                    91604           120
# 44656                    CA                    91604            79
# 44657                    CA                    91604            84
# 44659                    CA                    91604            32
# 44660                    CA                    91604            33
# 44661                    CA                    91604           123
# 44662                    CA                    91604            97
# 44663                    CA                    91604           119
# 44664                    CA                    91604            14
# 44665                    CA                    91604            21
# 44666                    CA                    91604            49
# 44667                    CA                    91604            12
# 44668                    CA                    91604           132
# 44669                    CA                    91604            22
# 44670                    CA                    91604             1
# 44671                    CA                    91604            48
# 44672                    CA                    91604             6
# 44673                    CA                    91604             7
# 44674                    CA                    91604            35
# 44675                    CA                    91604           225
# 44676                    CA                    91604            15
# 44677                    CA                    91604           448
# 44679                    CA                    91604            33
# 44680                    CA                    91604            33
# 44681                    CA                    91604           108
# 44682                    CA                    91604            95
# 44683                    CA                    91604           184
# 44684                    CA                    91604           229
# 44685                    CA                    91604             1
# 44686                    CA                    91604           207
#
# [20960 rows x 32 columns]

# %%
mean_adpt_time_size = {}
#create a dict with each state and average adoption time
for current_state,current_city in state.items():
    key = current_state
    val = alldogs_merged[(alldogs_merged['contact.address.state'] == current_state) & (alldogs_merged['size'] == 'Medium')]['adoption_time'].mean()
    mean_adpt_time[key] = val
pprint(mean_adpt_time)
# Out:
# {'CA': 200.739124420776,
#  'MN': 90.14137138710848,
#  'NY': 253.74362880316193,
#  'TX': 141.20239458615305}

# %%
mean_adpt_time_gender = {}
#create a dict with each state and average adoption time
for current_state,current_city in state.items():
    key = current_state
    val = alldogs_merged[(alldogs_merged['contact.address.state'] == current_state) & (alldogs_merged['gender'] == 'Female')]['adoption_time'].mean()
    mean_adpt_time[key] = val
pprint(mean_adpt_time)
# Out:
# {'CA': 177.13336104951958,
#  'MN': 101.01845779068678,
#  'NY': 219.14604960773437,
#  'TX': 132.6824194913367}

# %%
{key: value for key, value in sorted(mean_adpt_time.items(), key=lambda item: item[1])}
# Out:
# {'MN': 102.96562054208273,
#  'TX': 140.0659042704393,
#  'CA': 184.01237496363595,
#  'NY': 227.69666935576814}

# %%
var_adpt_time = {}
#create a dict with each state and average adoption time
for current_state,current_city in state.items():
    key = current_state
    val = alldogs_merged[alldogs_merged['contact.address.state'] == current_state]['adoption_time'].std()
    var_adpt_time[key] = val
pprint(var_adpt_time)
# Out:
# {'CA': 407.849730568399,
#  'MN': 231.9485312951107,
#  'NY': 469.75063786819663,
#  'TX': 312.5506962941683}

# %%
# Check for any missing data
print("Table size -", end=' ')
print(alldogs_merged.shape)

print("Checking for missing values..")
# Number of missing values in each column of training data
missing_val_count_by_column = (alldogs_merged.isnull().sum())
print(missing_val_count_by_column[missing_val_count_by_column > 0])

# Get names of columns with missing values
missing_cols = [col for col in alldogs_merged.columns
                     if alldogs_merged[col].isnull().any()]
# Out:
# Table size - (184542, 32)
# Checking for missing values..
# coat                     90130
# name                        34
# breeds.secondary        108920
# colors.primary           72624
# colors.secondary        126223
# colors.tertiary         182805
# attributes.declawed     184542
# environment.children    153131
# environment.dogs        149322
# environment.cats        165761
# dtype: int64

# %%
type(missing_cols)
# Out:
# list

# %%
alldogs_nm = alldogs_merged.drop(missing_cols, axis=1)

# %%
alldogs_nm.head()
# Out:
#          id organization_id  \
# 0  33853923          CA2395
# 1  33853969          CA2395
# 2  34004290          CA2395
# 3  34042721          CA2395
# 4  34079567          CA2395
#
#                                                  url    age  gender    size  \
# 0  https://www.petfinder.com/dog/sunny-33853923/c...   Baby  Female   Small
# 1  https://www.petfinder.com/dog/batman-33853969/...  Young    Male   Small
# 2  https://www.petfinder.com/dog/benji-34004290/c...  Young    Male  Medium
# 3  https://www.petfinder.com/dog/zuma-34042721/ca...  Adult  Female  Medium
# 4  https://www.petfinder.com/dog/diego-34079567/c...  Young    Male  Medium
#
#   tags   status         status_changed_at              published_at  ...  \
# 0   []  adopted  2015-12-11T20:50:51+0000  2015-11-22T20:02:14+0000  ...
# 1   []  adopted  2015-12-21T22:23:16+0000  2015-11-22T20:05:42+0000  ...
# 2   []  adopted  2015-12-30T01:22:04+0000  2015-12-11T20:55:05+0000  ...
# 3   []  adopted  2016-02-12T19:13:27+0000  2015-12-16T21:51:44+0000  ...
# 4   []  adopted  2015-12-30T01:21:59+0000  2015-12-21T22:22:57+0000  ...
#
#    breeds.mixed breeds.unknown  attributes.spayed_neutered  \
# 0          True          False                        True
# 1         False          False                        True
# 2         False          False                        True
# 3         False          False                        True
# 4          True          False                        True
#
#    attributes.house_trained  attributes.special_needs  \
# 0                      True                     False
# 1                      True                     False
# 2                     False                     False
# 3                     False                     False
# 4                     False                     False
#
#    attributes.shots_current  contact.address.city  contact.address.state  \
# 0                      True           Los Angeles                     CA
# 1                      True           Los Angeles                     CA
# 2                      True           Los Angeles                     CA
# 3                      True           Los Angeles                     CA
# 4                      True           Los Angeles                     CA
#
#   contact.address.postcode adoption_time
# 0                    90013            19
# 1                    90013            29
# 2                    90013            18
# 3                    90013            57
# 4                    90013             8
#
# [5 rows x 22 columns]

# %%
#remove negative days error
alldogs_nm = alldogs_nm[alldogs_nm['adoption_time']>=0]

# %%
alldogs_nm.columns
# Out:
# Index(['id', 'organization_id', 'url', 'age', 'gender', 'size', 'tags',
#        'status', 'status_changed_at', 'published_at', 'distance',
#        'breeds.primary', 'breeds.mixed', 'breeds.unknown',
#        'attributes.spayed_neutered', 'attributes.house_trained',
#        'attributes.special_needs', 'attributes.shots_current',
#        'contact.address.city', 'contact.address.state',
#        'contact.address.postcode', 'adoption_time'],
#       dtype='object')

# %%
X_features = ['age', 'gender', 'size',
       'breeds.mixed', 'breeds.unknown',
       'attributes.spayed_neutered', 'attributes.house_trained',
       'attributes.special_needs', 'attributes.shots_current', 'contact.address.state']
X = alldogs_nm[X_features]
X.head()
# Out:
#      age  gender    size  breeds.mixed  breeds.unknown  \
# 0   Baby  Female   Small          True           False
# 1  Young    Male   Small         False           False
# 2  Young    Male  Medium         False           False
# 3  Adult  Female  Medium         False           False
# 4  Young    Male  Medium          True           False
#
#    attributes.spayed_neutered  attributes.house_trained  \
# 0                        True                      True
# 1                        True                      True
# 2                        True                     False
# 3                        True                     False
# 4                        True                     False
#
#    attributes.special_needs  attributes.shots_current contact.address.state
# 0                     False                      True                    CA
# 1                     False                      True                    CA
# 2                     False                      True                    CA
# 3                     False                      True                    CA
# 4                     False                      True                    CA

# %%
X.dtypes
# Out:
# age                           object
# gender                        object
# size                          object
# breeds.mixed                    bool
# breeds.unknown                  bool
# attributes.spayed_neutered      bool
# attributes.house_trained        bool
# attributes.special_needs        bool
# attributes.shots_current        bool
# contact.address.state         object
# dtype: object

# %%
X['age'].value_counts()
# Out:
# Young     69406
# Baby      57013
# Adult     52537
# Senior     5586
# Name: age, dtype: int64

# %%
X['gender'].value_counts()
# Out:
# Male       93623
# Female     90683
# Unknown      236
# Name: gender, dtype: int64

# %%
X['size'].value_counts()
# Out:
# Medium         74496
# Small          71369
# Large          36036
# Extra Large     2641
# Name: size, dtype: int64

# %%
X['contact.address.state'].value_counts()
# Out:
# NY    52062
# TX    45733
# CA    44687
# MN    42060
# Name: contact.address.state, dtype: int64

# %%
test = alldogs_merged['name'].value_counts()
test[test>10]
# Out:
# Bella        598
# Max          566
# Daisy        551
# Buddy        540
# Lucy         524
# Charlie      509
# Molly        430
# Jack         424
# Lola         382
# Rocky        347
# Bailey       346
# Ginger       346
# Sadie        331
# Bear         327
# Toby         322
# Maggie       317
# Penny        308
# Lady         302
# Rosie        298
# Lucky        293
# Coco         292
# Luna         286
# Sophie       279
# Duke         279
# Princess     274
# Buster       261
# Teddy        255
# Lily         254
# Stella       252
# Ruby         251
#             ...
# Chaplin       11
# Petal         11
# Rylee         11
# Julian        11
# Starbuck      11
# Pokey         11
# Shine         11
# SPOT          11
# Hickory       11
# Guppy         11
# Poppi         11
# Churro        11
# DUNCAN        11
# Kyra          11
# Conan         11
# Raider        11
# Lightning     11
# CHESTER       11
# Ana           11
# JOY           11
# AUSTIN        11
# STAR          11
# Peppy         11
# Tootie        11
# Charlene      11
# Creed         11
# Delia         11
# Peppa         11
# Lindsay       11
# LIBBY         11
# Name: name, Length: 2572, dtype: int64

# %%
test.to_csv('names.csv', header=False, index=True)

# %%
X
# Out:
#            age  gender    size  breeds.mixed  breeds.unknown  \
# 0         Baby  Female   Small          True           False
# 1        Young    Male   Small         False           False
# 2        Young    Male  Medium         False           False
# 3        Adult  Female  Medium         False           False
# 4        Young    Male  Medium          True           False
# 5        Adult  Female   Small         False           False
# 6        Young  Female   Small          True           False
# 7        Young    Male   Small          True           False
# 8        Young    Male   Small          True           False
# 9        Adult  Female  Medium         False           False
# 10       Young    Male   Small          True           False
# 11       Young  Female  Medium          True           False
# 12       Young    Male   Small          True           False
# 13        Baby    Male   Small         False           False
# 14        Baby  Female  Medium          True           False
# 15        Baby  Female  Medium          True           False
# 16       Young  Female   Small          True           False
# 17       Young  Female   Small         False           False
# 18       Young  Female   Small          True           False
# 19        Baby    Male   Small          True           False
# 20       Young    Male   Small          True           False
# 21        Baby  Female   Small          True           False
# 22       Young    Male   Small          True           False
# 23        Baby    Male   Large          True           False
# 24       Young    Male   Small          True           False
# 25        Baby  Female  Medium          True           False
# 26       Young    Male   Small          True           False
# 27       Adult    Male   Small          True           False
# 28       Young    Male   Small          True           False
# 29       Young  Female   Small          True           False
# ...        ...     ...     ...           ...             ...
# 184512   Adult    Male  Medium          True           False
# 184513   Adult    Male  Medium          True           False
# 184514   Adult  Female   Large          True           False
# 184515   Adult  Female   Large          True           False
# 184516   Adult    Male   Small          True           False
# 184517  Senior    Male   Small          True           False
# 184518    Baby    Male   Large          True           False
# 184519   Adult    Male   Small          True           False
# 184520   Adult    Male   Small          True           False
# 184521   Adult  Female  Medium          True           False
# 184522   Young    Male   Small          True           False
# 184523   Adult  Female   Small          True           False
# 184524   Adult    Male   Small          True           False
# 184525   Adult    Male   Small          True           False
# 184526   Adult    Male   Large          True           False
# 184527   Adult  Female  Medium          True           False
# 184528   Adult  Female   Small          True           False
# 184529   Adult    Male   Small          True           False
# 184530   Adult  Female   Small          True           False
# 184531   Adult    Male   Small          True           False
# 184532   Adult    Male   Small          True           False
# 184533   Young  Female   Small          True           False
# 184534   Adult  Female  Medium          True           False
# 184535    Baby  Female  Medium          True           False
# 184536   Young    Male  Medium          True           False
# 184537   Young    Male   Small          True           False
# 184538   Adult  Female  Medium          True           False
# 184539   Adult  Female  Medium          True           False
# 184540   Adult    Male   Small          True           False
# 184541   Adult    Male   Small          True           False
#
#         attributes.spayed_neutered  attributes.house_trained  \
# 0                             True                      True
# 1                             True                      True
# 2                             True                     False
# 3                             True                     False
# 4                             True                     False
# 5                             True                     False
# 6                            False                     False
# 7                             True                     False
# 8                             True                     False
# 9                             True                     False
# 10                            True                      True
# 11                           False                     False
# 12                            True                      True
# 13                           False                      True
# 14                           False                      True
# 15                           False                      True
# 16                           False                      True
# 17                            True                     False
# 18                            True                      True
# 19                           False                     False
# 20                            True                      True
# 21                           False                      True
# 22                            True                     False
# 23                            True                     False
# 24                            True                      True
# 25                            True                     False
# 26                            True                     False
# 27                            True                     False
# 28                           False                      True
# 29                            True                     False
# ...                            ...                       ...
# 184512                        True                     False
# 184513                        True                     False
# 184514                        True                     False
# 184515                        True                     False
# 184516                        True                     False
# 184517                        True                      True
# 184518                       False                     False
# 184519                        True                     False
# 184520                        True                     False
# 184521                        True                     False
# 184522                        True                     False
# 184523                        True                     False
# 184524                        True                     False
# 184525                        True                     False
# 184526                        True                      True
# 184527                        True                     False
# 184528                        True                     False
# 184529                        True                     False
# 184530                        True                     False
# 184531                        True                     False
# 184532                        True                     False
# 184533                        True                     False
# 184534                        True                      True
# 184535                        True                     False
# 184536                        True                     False
# 184537                        True                     False
# 184538                        True                     False
# 184539                        True                     False
# 184540                        True                     False
# 184541                        True                     False
#
#         attributes.special_needs  attributes.shots_current  \
# 0                          False                      True
# 1                          False                      True
# 2                          False                      True
# 3                          False                      True
# 4                          False                      True
# 5                          False                      True
# 6                          False                     False
# 7                          False                      True
# 8                          False                      True
# 9                          False                      True
# 10                         False                      True
# 11                         False                     False
# 12                         False                      True
# 13                         False                      True
# 14                         False                     False
# 15                         False                      True
# 16                         False                      True
# 17                         False                      True
# 18                         False                      True
# 19                         False                      True
# 20                         False                      True
# 21                         False                      True
# 22                         False                      True
# 23                         False                      True
# 24                         False                      True
# 25                         False                      True
# 26                         False                      True
# 27                         False                      True
# 28                         False                      True
# 29                         False                      True
# ...                          ...                       ...
# 184512                     False                      True
# 184513                     False                      True
# 184514                     False                      True
# 184515                     False                      True
# 184516                     False                      True
# 184517                     False                      True
# 184518                     False                      True
# 184519                     False                      True
# 184520                     False                      True
# 184521                     False                      True
# 184522                     False                      True
# 184523                     False                      True
# 184524                     False                      True
# 184525                     False                      True
# 184526                     False                      True
# 184527                     False                      True
# 184528                     False                      True
# 184529                     False                      True
# 184530                     False                      True
# 184531                     False                      True
# 184532                     False                      True
# 184533                     False                      True
# 184534                     False                      True
# 184535                     False                      True
# 184536                     False                      True
# 184537                     False                      True
# 184538                     False                      True
# 184539                     False                      True
# 184540                     False                      True
# 184541                     False                      True
#
#        contact.address.state
# 0                         CA
# 1                         CA
# 2                         CA
# 3                         CA
# 4                         CA
# 5                         CA
# 6                         CA
# 7                         CA
# 8                         CA
# 9                         CA
# 10                        CA
# 11                        CA
# 12                        CA
# 13                        CA
# 14                        CA
# 15                        CA
# 16                        CA
# 17                        CA
# 18                        CA
# 19                        CA
# 20                        CA
# 21                        CA
# 22                        CA
# 23                        CA
# 24                        CA
# 25                        CA
# 26                        CA
# 27                        CA
# 28                        CA
# 29                        CA
# ...                      ...
# 184512                    TX
# 184513                    TX
# 184514                    TX
# 184515                    TX
# 184516                    TX
# 184517                    TX
# 184518                    TX
# 184519                    TX
# 184520                    TX
# 184521                    TX
# 184522                    TX
# 184523                    TX
# 184524                    TX
# 184525                    TX
# 184526                    TX
# 184527                    TX
# 184528                    TX
# 184529                    TX
# 184530                    TX
# 184531                    TX
# 184532                    TX
# 184533                    TX
# 184534                    TX
# 184535                    TX
# 184536                    TX
# 184537                    TX
# 184538                    TX
# 184539                    TX
# 184540                    TX
# 184541                    TX
#
# [184542 rows x 10 columns]

# %%
y = alldogs_nm['adoption_time']

# %%
cat_col = ['age','gender','size','contact.address.state']

# %%
X[cat_col]=X[cat_col].astype('category')
# Out:
# C:\anaconda_python\lib\site-packages\pandas\core\frame.py:3391: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[k1] = value[k2]

# %%
X.dtypes
# Out:
# age                           category
# gender                        category
# size                          category
# breeds.mixed                      bool
# breeds.unknown                    bool
# attributes.spayed_neutered        bool
# attributes.house_trained          bool
# attributes.special_needs          bool
# attributes.shots_current          bool
# contact.address.state         category
# dtype: object

# %%
total = pd.concat([X,y], axis=1)
total.dtypes
# Out:
# age                           category
# gender                        category
# size                          category
# breeds.mixed                      bool
# breeds.unknown                    bool
# attributes.spayed_neutered        bool
# attributes.house_trained          bool
# attributes.special_needs          bool
# attributes.shots_current          bool
# contact.address.state         category
# adoption_time                    int64
# dtype: object

# %%
total
# Out:
#            age  gender    size  breeds.mixed  breeds.unknown  \
# 0         Baby  Female   Small          True           False
# 1        Young    Male   Small         False           False
# 2        Young    Male  Medium         False           False
# 3        Adult  Female  Medium         False           False
# 4        Young    Male  Medium          True           False
# 5        Adult  Female   Small         False           False
# 6        Young  Female   Small          True           False
# 7        Young    Male   Small          True           False
# 8        Young    Male   Small          True           False
# 9        Adult  Female  Medium         False           False
# 10       Young    Male   Small          True           False
# 11       Young  Female  Medium          True           False
# 12       Young    Male   Small          True           False
# 13        Baby    Male   Small         False           False
# 14        Baby  Female  Medium          True           False
# 15        Baby  Female  Medium          True           False
# 16       Young  Female   Small          True           False
# 17       Young  Female   Small         False           False
# 18       Young  Female   Small          True           False
# 19        Baby    Male   Small          True           False
# 20       Young    Male   Small          True           False
# 21        Baby  Female   Small          True           False
# 22       Young    Male   Small          True           False
# 23        Baby    Male   Large          True           False
# 24       Young    Male   Small          True           False
# 25        Baby  Female  Medium          True           False
# 26       Young    Male   Small          True           False
# 27       Adult    Male   Small          True           False
# 28       Young    Male   Small          True           False
# 29       Young  Female   Small          True           False
# ...        ...     ...     ...           ...             ...
# 184512   Adult    Male  Medium          True           False
# 184513   Adult    Male  Medium          True           False
# 184514   Adult  Female   Large          True           False
# 184515   Adult  Female   Large          True           False
# 184516   Adult    Male   Small          True           False
# 184517  Senior    Male   Small          True           False
# 184518    Baby    Male   Large          True           False
# 184519   Adult    Male   Small          True           False
# 184520   Adult    Male   Small          True           False
# 184521   Adult  Female  Medium          True           False
# 184522   Young    Male   Small          True           False
# 184523   Adult  Female   Small          True           False
# 184524   Adult    Male   Small          True           False
# 184525   Adult    Male   Small          True           False
# 184526   Adult    Male   Large          True           False
# 184527   Adult  Female  Medium          True           False
# 184528   Adult  Female   Small          True           False
# 184529   Adult    Male   Small          True           False
# 184530   Adult  Female   Small          True           False
# 184531   Adult    Male   Small          True           False
# 184532   Adult    Male   Small          True           False
# 184533   Young  Female   Small          True           False
# 184534   Adult  Female  Medium          True           False
# 184535    Baby  Female  Medium          True           False
# 184536   Young    Male  Medium          True           False
# 184537   Young    Male   Small          True           False
# 184538   Adult  Female  Medium          True           False
# 184539   Adult  Female  Medium          True           False
# 184540   Adult    Male   Small          True           False
# 184541   Adult    Male   Small          True           False
#
#         attributes.spayed_neutered  attributes.house_trained  \
# 0                             True                      True
# 1                             True                      True
# 2                             True                     False
# 3                             True                     False
# 4                             True                     False
# 5                             True                     False
# 6                            False                     False
# 7                             True                     False
# 8                             True                     False
# 9                             True                     False
# 10                            True                      True
# 11                           False                     False
# 12                            True                      True
# 13                           False                      True
# 14                           False                      True
# 15                           False                      True
# 16                           False                      True
# 17                            True                     False
# 18                            True                      True
# 19                           False                     False
# 20                            True                      True
# 21                           False                      True
# 22                            True                     False
# 23                            True                     False
# 24                            True                      True
# 25                            True                     False
# 26                            True                     False
# 27                            True                     False
# 28                           False                      True
# 29                            True                     False
# ...                            ...                       ...
# 184512                        True                     False
# 184513                        True                     False
# 184514                        True                     False
# 184515                        True                     False
# 184516                        True                     False
# 184517                        True                      True
# 184518                       False                     False
# 184519                        True                     False
# 184520                        True                     False
# 184521                        True                     False
# 184522                        True                     False
# 184523                        True                     False
# 184524                        True                     False
# 184525                        True                     False
# 184526                        True                      True
# 184527                        True                     False
# 184528                        True                     False
# 184529                        True                     False
# 184530                        True                     False
# 184531                        True                     False
# 184532                        True                     False
# 184533                        True                     False
# 184534                        True                      True
# 184535                        True                     False
# 184536                        True                     False
# 184537                        True                     False
# 184538                        True                     False
# 184539                        True                     False
# 184540                        True                     False
# 184541                        True                     False
#
#         attributes.special_needs  attributes.shots_current  \
# 0                          False                      True
# 1                          False                      True
# 2                          False                      True
# 3                          False                      True
# 4                          False                      True
# 5                          False                      True
# 6                          False                     False
# 7                          False                      True
# 8                          False                      True
# 9                          False                      True
# 10                         False                      True
# 11                         False                     False
# 12                         False                      True
# 13                         False                      True
# 14                         False                     False
# 15                         False                      True
# 16                         False                      True
# 17                         False                      True
# 18                         False                      True
# 19                         False                      True
# 20                         False                      True
# 21                         False                      True
# 22                         False                      True
# 23                         False                      True
# 24                         False                      True
# 25                         False                      True
# 26                         False                      True
# 27                         False                      True
# 28                         False                      True
# 29                         False                      True
# ...                          ...                       ...
# 184512                     False                      True
# 184513                     False                      True
# 184514                     False                      True
# 184515                     False                      True
# 184516                     False                      True
# 184517                     False                      True
# 184518                     False                      True
# 184519                     False                      True
# 184520                     False                      True
# 184521                     False                      True
# 184522                     False                      True
# 184523                     False                      True
# 184524                     False                      True
# 184525                     False                      True
# 184526                     False                      True
# 184527                     False                      True
# 184528                     False                      True
# 184529                     False                      True
# 184530                     False                      True
# 184531                     False                      True
# 184532                     False                      True
# 184533                     False                      True
# 184534                     False                      True
# 184535                     False                      True
# 184536                     False                      True
# 184537                     False                      True
# 184538                     False                      True
# 184539                     False                      True
# 184540                     False                      True
# 184541                     False                      True
#
#        contact.address.state  adoption_time
# 0                         CA             19
# 1                         CA             29
# 2                         CA             18
# 3                         CA             57
# 4                         CA              8
# 5                         CA             33
# 6                         CA             13
# 7                         CA             14
# 8                         CA             32
# 9                         CA             14
# 10                        CA             25
# 11                        CA              3
# 12                        CA              5
# 13                        CA              1
# 14                        CA              5
# 15                        CA              5
# 16                        CA             34
# 17                        CA             10
# 18                        CA             16
# 19                        CA             36
# 20                        CA             30
# 21                        CA             22
# 22                        CA             44
# 23                        CA             57
# 24                        CA             25
# 25                        CA             12
# 26                        CA             97
# 27                        CA             49
# 28                        CA              4
# 29                        CA             36
# ...                      ...            ...
# 184512                    TX           1439
# 184513                    TX           1439
# 184514                    TX           1434
# 184515                    TX           1434
# 184516                    TX           1430
# 184517                    TX           1425
# 184518                    TX           1425
# 184519                    TX           1425
# 184520                    TX           1425
# 184521                    TX           1425
# 184522                    TX           1425
# 184523                    TX           1425
# 184524                    TX           1425
# 184525                    TX           1425
# 184526                    TX           1424
# 184527                    TX           1421
# 184528                    TX           1421
# 184529                    TX           1416
# 184530                    TX           1410
# 184531                    TX           1410
# 184532                    TX           1410
# 184533                    TX           1410
# 184534                    TX           1404
# 184535                    TX           1401
# 184536                    TX           1381
# 184537                    TX           1381
# 184538                    TX           1381
# 184539                    TX           1380
# 184540                    TX           1380
# 184541                    TX           1380
#
# [184542 rows x 11 columns]

# %%
sizeplot = sns.catplot(x='size', y='adoption_time', order=["Small", "Medium", "Large", "Extra Large"] , data=total, kind='boxen');

# %%
sizeplot2 = sns.catplot(x='size', y='adoption_time', order=["Small", "Medium", "Large", "Extra Large"] , data=total, kind='box');
sizeplot2.set(ylim=(0,300))

# %%
sns.catplot(x='contact.address.state', y='adoption_time', kind="boxen", data=total);

# %%
sizeplot3 = sns.catplot(x='contact.address.state', y='adoption_time', order=["CA", "MN", "NY", "TX"] , data=total, kind='box');
sizeplot3.set(ylim=(0,300))

# %%
sns.catplot(x="contact.address.state", kind="count", palette="ch:.25", data=total);

# %%
from sklearn.model_selection import train_test_split
trainval_X, test_X, trainval_y, test_y = train_test_split(X, y, test_size=0.2, random_state = 0)
print('Training set size = {} and Test set size = {}'.format(len(trainval_X),len(test_X)))
# Out:
# Training set size = 147633 and Test set size = 36909

# %%
total_test = pd.concat([test_X,test_y], axis=1)

# %%
export = total_test.to_csv('./data/test_set_scoped.csv', header=True, index = False)

# %%
total_trainval = pd.concat([trainval_X,trainval_y], axis=1)

# %%
export = total_trainval.to_csv('./data/trainval_set_scoped.csv', header=True, index = False)
