# %%
#merge data from several states
import numpy as np
import pandas as pd
import json
from pandas.io.json import json_normalize

# %%
state_info = pd.read_csv('stats_all.csv')
state_pos = 0
current_state = state_info['state'][state_pos]
current_city = state_info['city'][state_pos]
current_state
# Out:
# 'AL'

# %%
alldogs_merged = pd.read_csv('./data_all/alldogs_reduced_{}.csv'.format(current_state))

# %%
alldogs_merged.head()
# Out:
#          id organization_id  \
# 0  24113097           CA712
# 1  35898350           CA712
# 2  30542160          TX1860
# 3  41000971           FL653
# 4  33618001           FL653
#
#                                                  url    age  gender  \
# 0  https://www.petfinder.com/dog/madonna-24113097...  Adult  Female
# 1  https://www.petfinder.com/dog/bess-located-in-...  Adult  Female
# 2  https://www.petfinder.com/dog/madonna-30542160...  Young  Female
# 3  https://www.petfinder.com/dog/al-sweetie-birmi...  Adult  Female
# 4  https://www.petfinder.com/dog/al-rosie-prattvi...  Young  Female
#
#           size    coat tags                             name   status  ...  \
# 0        Small    Long   []                          Madonna  adopted  ...
# 1        Small   Short   []  Bess (located in Birmingam, AL)  adopted  ...
# 2        Small  Medium   []                          Madonna  adopted  ...
# 3  Extra Large   Short   []          AL - Sweetie/Birmingham  adopted  ...
# ...

# %%
len(alldogs_merged)
# Out:
# 39169

# %%
for state_pos in range(1,49):
    current_state = state_info['state'][state_pos]
    current_city = state_info['city'][state_pos]
    print('Processing state {} - {}'.format(state_pos, current_state))
    temp = pd.read_csv('./data_all/alldogs_reduced_{}.csv'.format(current_state))
    frames = [alldogs_merged, temp]
    alldogs_merged = pd.concat(frames)
# Out:
# Processing state 1 - AK
# Processing state 2 - AZ
# Processing state 3 - AR
# Processing state 4 - CA
# Processing state 5 - CO
# Processing state 6 - CT
# Processing state 7 - DE
# C:\anaconda_python\envs\Insight\lib\site-packages\ipykernel_launcher.py:7: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   import sys
# Processing state 8 - FL
# Processing state 9 - GA
# Processing state 10 - ID
# Processing state 11 - IL
# Processing state 12 - IN
# Processing state 13 - IA
# Processing state 14 - KS
# Processing state 15 - KY
# Processing state 16 - LA
# Processing state 17 - ME
# Processing state 18 - MD
# Processing state 19 - MA
# Processing state 20 - MI
# Processing state 21 - MN
# Processing state 22 - MS
# Processing state 23 - MO
# Processing state 24 - MT
# ...

# %%
len(alldogs_merged)
# Out:
# 1472050

# %%
while(state_pos<7):
    current_state = state_info['state'][state_pos]
    current_city = state_info['city'][state_pos]
    temp = pd.read_csv('alldogs_reduced_{}.csv'.format(current_state))
    frames = [alldogs_merged, temp]
    alldogs_merged = pd.concat(frames)
    state_pos=state_pos+1

# %%
len(alldogs_merged)
# Out:
# 265324

# %%
export = alldogs_merged.to_csv('./data_all/alldogs_merged_all.csv', header=True, index = False)

# %%
alldogs_merged = []
state={'CA':'Los Angeles', 'MN': 'Minneapolis', 'NY':'New York', 'TX': 'Houston'}

# %%
for current_state,current_city in state.items():
    temp = pd.read_csv('./data/alldogs_reduced_{}.csv'.format(current_state))
    alldogs_merged.append(temp)
# Out:
# C:\anaconda_python\envs\Insight\lib\site-packages\IPython\core\interactiveshell.py:3051: DtypeWarning: Columns (19) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
alldogs_merged = pd.concat(alldogs_merged)
alldogs_merged
# Out:
#              id organization_id  \
# 0      33853923          CA2395
# 1      33853969          CA2395
# 2      34004290          CA2395
# 3      34042721          CA2395
# 4      34079567          CA2395
# ...         ...             ...
# 45728   7010081           TX734
# 45729   7010119           TX734
# 45730   7012295           TX734
# 45731   7012305           TX734
# 45732   7012313           TX734
#
#                                                      url    age  gender  \
# 0      https://www.petfinder.com/dog/sunny-33853923/c...   Baby  Female
# 1      https://www.petfinder.com/dog/batman-33853969/...  Young    Male
# 2      https://www.petfinder.com/dog/benji-34004290/c...  Young    Male
# 3      https://www.petfinder.com/dog/zuma-34042721/ca...  Adult  Female
# 4      https://www.petfinder.com/dog/diego-34079567/c...  Young    Male
# ...                                                  ...    ...     ...
# ...

# %%
export = alldogs_merged.to_csv('./data/alldogs_scoped_merged.csv', header=True, index = False)
