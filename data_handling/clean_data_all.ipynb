# %%
import numpy as np
import pandas as pd
import json
from pandas.io.json import json_normalize

# %%
state_info = pd.read_csv('stats_all.csv')

# %%
state_info
# Out:
#    state            city  total  total_correct_city  max_dist  max_dist_city  \
# 0     AL      Birmingham  39005              1445.0   99.6295        13.3825
# 1     AK       Anchorage   2769              2516.0   78.5158         8.8004
# 2     AZ         Phoenix  59766             17393.0   99.8284        32.4871
# 3     AR     Little Rock  22584               509.0   97.0427        10.2831
# 4     CA     Los Angeles  44687             28564.0   10.4834        10.4192
# 5     CO          Denver  85222              8587.0   99.8258        10.8111
# 6     CT      Bridgeport  11291              1036.0   15.9824         2.3724
# 7     DE      Wilmington     -1                 NaN       NaN            NaN
# 8     FL    Jacksonville     -1                 NaN       NaN            NaN
# 9     GA         Atlanta     -1                 NaN       NaN            NaN
# 10    ID           Boise     -1                 NaN       NaN            NaN
# 11    IL         Chicago     -1                 NaN       NaN            NaN
# 12    IN    Indianapolis     -1                 NaN       NaN            NaN
# 13    IA      Des Moines     -1                 NaN       NaN            NaN
# 14    KS         Wichita     -1                 NaN       NaN            NaN
# 15    KY      Louisville     -1                 NaN       NaN            NaN
# 16    LA     New Orleans     -1                 NaN       NaN            NaN
# 17    ME        Portland     -1                 NaN       NaN            NaN
# 18    MD       Baltimore     -1                 NaN       NaN            NaN
# 19    MA          Boston     -1                 NaN       NaN            NaN
# 20    MI         Detroit     -1                 NaN       NaN            NaN
# 21    MN     Minneapolis     -1                 NaN       NaN            NaN
# 22    MS         Jackson     -1                 NaN       NaN            NaN
# 23    MO     Kansas City     -1                 NaN       NaN            NaN
# 24    MT        Billings     -1                 NaN       NaN            NaN
# 25    NE           Omaha     -1                 NaN       NaN            NaN
# 26    NV       Las Vegas     -1                 NaN       NaN            NaN
# 27    NH      Manchester     -1                 NaN       NaN            NaN
# 28    NJ          Newark     -1                 NaN       NaN            NaN
# 29    NM     Albuquerque     -1                 NaN       NaN            NaN
# 30    NY        New York  85059             15988.0   21.6517        12.4244
# 31    NC       Charlotte     -1                 NaN       NaN            NaN
# 32    ND           Fargo     -1                 NaN       NaN            NaN
# 33    OH        Columbus     -1                 NaN       NaN            NaN
# 34    OK   Oklahoma City     -1                 NaN       NaN            NaN
# 35    OR        Portland     -1                 NaN       NaN            NaN
# 36    PA    Philadelphia     -1                 NaN       NaN            NaN
# 37    RI      Providence     -1                 NaN       NaN            NaN
# 38    SC      Charleston     -1                 NaN       NaN            NaN
# 39    SD     Sioux Falls     -1                 NaN       NaN            NaN
# 40    TN       Nashville     -1                 NaN       NaN            NaN
# 41    TX         Houston     -1                 NaN       NaN            NaN
# 42    UT  Salt Lake City     -1                 NaN       NaN            NaN
# 43    VT      Burlington     -1                 NaN       NaN            NaN
# 44    VA  Virginia Beach     -1                 NaN       NaN            NaN
# 45    WA         Seattle     -1                 NaN       NaN            NaN
# 46    WV      Charleston     -1                 NaN       NaN            NaN
# 47    WI       Milwaukee     -1                 NaN       NaN            NaN
# 48    WY        Cheyenne     -1                 NaN       NaN            NaN
#
#     bad_dates
# 0       714.0
# 1       102.0
# 2      1154.0
# 3       184.0
# 4       301.0
# 5      1684.0
# 6       406.0
# 7         NaN
# 8         NaN
# 9         NaN
# 10        NaN
# 11        NaN
# 12        NaN
# 13        NaN
# 14        NaN
# 15        NaN
# 16        NaN
# 17        NaN
# 18        NaN
# 19        NaN
# 20        NaN
# 21        NaN
# 22        NaN
# 23        NaN
# 24        NaN
# 25        NaN
# 26        NaN
# 27        NaN
# 28        NaN
# 29        NaN
# 30     4584.0
# 31        NaN
# 32        NaN
# 33        NaN
# 34        NaN
# 35        NaN
# 36        NaN
# 37        NaN
# 38        NaN
# 39        NaN
# 40        NaN
# 41        NaN
# 42        NaN
# 43        NaN
# 44        NaN
# 45        NaN
# 46        NaN
# 47        NaN
# 48        NaN

# %%
from datetime import datetime
def get_diff(end, start):
    end_d = datetime.strptime(end,"%Y-%m-%dT%H:%M:%S%z")
    start_d = datetime.strptime(start,"%Y-%m-%dT%H:%M:%S%z")
    if(end_d == start_d):
        return -1
    return (end_d - start_d).days

# %%
#from datetime import datetime
def get_month(date):
    z = datetime.strptime(date,"%Y-%m-%dT%H:%M:%S%z")
    return z.month

# %%
#from datetime import datetime
def get_year(date):
    z = datetime.strptime(date,"%Y-%m-%dT%H:%M:%S%z")
    return z.year

# %%
for i in range(0,49):
    current_state = state_info['state'][i]
    current_city = state_info['city'][i]
    print('Processing state {} - {}'.format(i, current_state))
    alldogs = pd.read_csv('./data_all/alldogs_{}.csv'.format(current_state))
    alldogs_reduced = alldogs.drop(['type', 'species', 'description', 'photos', 
                                    'contact.email', 'contact.phone', 'contact.address.address1', 
                                    'contact.address.address2', 'contact.address.country', 
                                    '_links.self.href', '_links.type.href', '_links.organization.href'], axis=1)
    alldogs_reduced = alldogs_reduced.drop_duplicates()
    alldogs_reduced = alldogs_reduced[alldogs_reduced['contact.address.state']==current_state]
    alldogs_reduced['adoption_time'] = alldogs_reduced.apply(lambda x: get_diff(x['status_changed_at'], x['published_at']), axis=1)
    bad_dates = len(alldogs_reduced[alldogs_reduced['adoption_time']==-1])
    alldogs_reduced = alldogs_reduced[alldogs_reduced['adoption_time']!=-1]
    alldogs_reduced['year'] = alldogs_reduced.apply(lambda x: get_year(x['status_changed_at']), axis=1)
    alldogs_reduced['month'] = alldogs_reduced.apply(lambda x: get_month(x['status_changed_at']), axis=1)
    state_info.loc[i , 'max_dist'] = alldogs_reduced['distance'].max()
    state_info.loc[i , 'bad_dates'] = bad_dates
    export = state_info.to_csv('stats_all.csv', header=True, index=False)
    export = alldogs_reduced.to_csv('./data_all/alldogs_reduced_{}.csv'.format(current_state), header=True, index = False)
# Out:
# Processing state 0 - AL
# Processing state 1 - AK
# Processing state 2 - AZ
# Processing state 3 - AR
# Processing state 4 - CA
# Processing state 5 - CO
# Processing state 6 - CT
# Processing state 7 - DE
# Processing state 8 - FL
# Processing state 9 - GA
# C:\anaconda_python\envs\Insight\lib\site-packages\IPython\core\interactiveshell.py:3051: DtypeWarning: Columns (18) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# Processing state 10 - ID
# Processing state 11 - IL
# C:\anaconda_python\envs\Insight\lib\site-packages\IPython\core\interactiveshell.py:3051: DtypeWarning: Columns (35) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# Processing state 12 - IN
# Processing state 13 - IA
# Processing state 14 - KS
# Processing state 15 - KY
# Processing state 16 - LA
# Processing state 17 - ME
# Processing state 18 - MD
# Processing state 19 - MA
# Processing state 20 - MI
# C:\anaconda_python\envs\Insight\lib\site-packages\IPython\core\interactiveshell.py:3051: DtypeWarning: Columns (35,38) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# Processing state 21 - MN
# Processing state 22 - MS
# Processing state 23 - MO
# Processing state 24 - MT
# Processing state 25 - NE
# Processing state 26 - NV
# Processing state 27 - NH
# Processing state 28 - NJ
# Processing state 29 - NM
# Processing state 30 - NY
# Processing state 31 - NC
# Processing state 32 - ND
# Processing state 33 - OH
# Processing state 34 - OK
# Processing state 35 - OR
# Processing state 36 - PA
# Processing state 37 - RI
# Processing state 38 - SC
# Processing state 39 - SD
# Processing state 40 - TN
# Processing state 41 - TX
# Processing state 42 - UT
# Processing state 43 - VT
# Processing state 44 - VA
# Processing state 45 - WA
# Processing state 46 - WV
# Processing state 47 - WI
# Processing state 48 - WY

# %%
alldogs = pd.read_csv('./data/alldogs_{}.csv'.format(current_state))
# Out:
# C:\anaconda_python\envs\Insight\lib\site-packages\IPython\core\interactiveshell.py:3051: DtypeWarning: Columns (35) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
readfile
# Out:
# 'alldogs_AL'

# %%
alldogs
# Out:
#              id organization_id  \
# 0       2604949           NY114
# 1       3821543           NY114
# 2       3924002           NY114
# 3       4115299           NY114
# 4       4127857           NY114
# ...         ...             ...
# 89995  37886284           VA524
# 89996  37919613           VA524
# 89997  37926806           VA524
# 89998  37935417           VA524
# 89999  37935443           VA524
#
#                                                      url type species     age  \
# 0      https://www.petfinder.com/dog/lexie-2604949/ny...  Dog     Dog   Young
# 1      https://www.petfinder.com/dog/poipu-3821543/ny...  Dog     Dog   Adult
# 2      https://www.petfinder.com/dog/nellie-3924002/n...  Dog     Dog   Adult
# 3      https://www.petfinder.com/dog/kiko-4115299/ny/...  Dog     Dog   Adult
# 4      https://www.petfinder.com/dog/princess-4127857...  Dog     Dog  Senior
# ...                                                  ...  ...     ...     ...
# 89995  https://www.petfinder.com/dog/daisy-37886284/n...  Dog     Dog    Baby
# 89996  https://www.petfinder.com/dog/willie-37919613/...  Dog     Dog   Young
# 89997  https://www.petfinder.com/dog/amber-37926806/n...  Dog     Dog   Young
# 89998  https://www.petfinder.com/dog/ensa-37935417/nj...  Dog     Dog    Baby
# 89999  https://www.petfinder.com/dog/orochi-37935443/...  Dog     Dog    Baby
#
#        gender    size    coat tags  ...       contact.phone  \
# 0      Female   Large     NaN   []  ...     (212) 252-3183
# 1      Female   Small     NaN   []  ...     (212) 252-3183
# 2      Female   Small     NaN   []  ...     (212) 252-3183
# 3        Male   Small     NaN   []  ...     (212) 252-3183
# 4      Female   Small     NaN   []  ...        212-691-2053
# ...       ...     ...     ...  ...  ...                 ...
# 89995  Female   Small   Short   []  ...  Please Email Us!
# 89996    Male   Small  Medium   []  ...  Please Email Us!
# 89997  Female  Medium   Short   []  ...  Please Email Us!
# 89998  Female   Small   Short   []  ...  Please Email Us!
# 89999    Male  Medium  Medium   []  ...  Please Email Us!
#
#       contact.address.address1 contact.address.address2 contact.address.city  \
# 0                P.O. Box 1345     Canal Street Station             New York
# 1                P.O. Box 1345     Canal Street Station             New York
# 2                P.O. Box 1345     Canal Street Station             New York
# 3                P.O. Box 1345     Canal Street Station             New York
# 4                P.O. Box 1345     Canal Street Station             New York
# ...                        ...                      ...                  ...
# 89995                      NaN                      NaN              Madison
# 89996                      NaN                      NaN              Madison
# 89997                      NaN                      NaN              Madison
# 89998                      NaN                      NaN              Madison
# 89999                      NaN                      NaN              Madison
#
#       contact.address.state contact.address.postcode  contact.address.country  \
# 0                        NY                    10013                       US
# 1                        NY                    10013                       US
# 2                        NY                    10013                       US
# 3                        NY                    10013                       US
# 4                        NY                    10013                       US
# ...                     ...                      ...                      ...
# 89995                    NJ                     7940                       US
# 89996                    NJ                     7940                       US
# 89997                    NJ                     7940                       US
# 89998                    NJ                     7940                       US
# 89999                    NJ                     7940                       US
#
#            _links.self.href _links.type.href  _links.organization.href
# 0       /v2/animals/2604949    /v2/types/dog   /v2/organizations/ny114
# 1       /v2/animals/3821543    /v2/types/dog   /v2/organizations/ny114
# 2       /v2/animals/3924002    /v2/types/dog   /v2/organizations/ny114
# 3       /v2/animals/4115299    /v2/types/dog   /v2/organizations/ny114
# 4       /v2/animals/4127857    /v2/types/dog   /v2/organizations/ny114
# ...                     ...              ...                       ...
# 89995  /v2/animals/37886284    /v2/types/dog   /v2/organizations/va524
# 89996  /v2/animals/37919613    /v2/types/dog   /v2/organizations/va524
# 89997  /v2/animals/37926806    /v2/types/dog   /v2/organizations/va524
# 89998  /v2/animals/37935417    /v2/types/dog   /v2/organizations/va524
# 89999  /v2/animals/37935443    /v2/types/dog   /v2/organizations/va524
#
# [90000 rows x 43 columns]
